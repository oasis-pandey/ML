# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv")

# %%
print(df.head())
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
print(df.tail(5))
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132       NaN
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %%
print(df.shape)
# Out:
# (32, 5)

# %%
print("Column names: ", df.columns)
# Out:
# Column names:  Index(['Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
print(df.dtypes)
# Out:
# Duration      int64
# Date         object
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
print(df.describe())
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %%
print(df.nunique())
# Out:
# Duration     4
# Date        30
# Pulse       15
# Maxpulse    24
# Calories    26
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
df.rename(columns= {'Duration':'Time Span'}, inplace = True)

# %%
df = df.iloc[:,[1,0,2,3,4]]

# %%
df.head()
# Out:
#    Time Span          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0

# %%
df['Calories2'] = df['Calories']

# %%
df.head()
# Out:
#    Time Span          Date  Pulse  Maxpulse  Calories  Calories2
# 0         60  '2020/12/01'    110       130     409.1      409.1
# 1         60  '2020/12/02'    117       145     479.0      479.0
# 2         60  '2020/12/03'    103       135     340.0      340.0
# 3         45  '2020/12/04'    109       175     282.4      282.4
# 4         45  '2020/12/05'    117       148     406.0      406.0

# %%
del df['Calories2']

# %%
df.head()
# Out:
#    Time Span          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0

# %%
df_copy = df.copy()

# %%
df = df.reset_index(drop = True)

# %%
df['Date'] = pd.to_datetime(df['Date'], errors= 'coerce')

# %%
df['Date'] = df['Date'].fillna('Unknown')

# %%
df=df.fillna(0)

# %%
print(df)
# Out:
#                    Date  Time Span  Pulse  Maxpulse  Calories
# 0   2020-12-01 00:00:00         60    110       130     409.1
# 1   2020-12-02 00:00:00         60    117       145     479.0
# 2   2020-12-03 00:00:00         60    103       135     340.0
# 3   2020-12-04 00:00:00         45    109       175     282.4
# 4   2020-12-05 00:00:00         45    117       148     406.0
# 5   2020-12-06 00:00:00         60    102       127     300.0
# 6   2020-12-07 00:00:00         60    110       136     374.0
# 7   2020-12-08 00:00:00        450    104       134     253.3
# 8   2020-12-09 00:00:00         30    109       133     195.1
# 9   2020-12-10 00:00:00         60     98       124     269.0
# 10  2020-12-11 00:00:00         60    103       147     329.3
# 11  2020-12-12 00:00:00         60    100       120     250.7
# 12  2020-12-12 00:00:00         60    100       120     250.7
# 13  2020-12-13 00:00:00         60    106       128     345.3
# 14  2020-12-14 00:00:00         60    104       132     379.3
# 15  2020-12-15 00:00:00         60     98       123     275.0
# 16  2020-12-16 00:00:00         60     98       120     215.2
# 17  2020-12-17 00:00:00         60    100       120     300.0
# 18  2020-12-18 00:00:00         45     90       112       0.0
# 19  2020-12-19 00:00:00         60    103       123     323.0
# 20  2020-12-20 00:00:00         45     97       125     243.0
# 21  2020-12-21 00:00:00         60    108       131     364.2
# 22              Unknown         45    100       119     282.0
# 23  2020-12-23 00:00:00         60    130       101     300.0
# 24  2020-12-24 00:00:00         45    105       132     246.0
# 25  2020-12-25 00:00:00         60    102       126     334.5
# 26              Unknown         60    100       120     250.0
# 27  2020-12-27 00:00:00         60     92       118     241.0
# 28  2020-12-28 00:00:00         60    103       132       0.0
# 29  2020-12-29 00:00:00         60    100       132     280.0
# 30  2020-12-30 00:00:00         60    102       129     380.3
# 31  2020-12-31 00:00:00         60     92       115     243.0

# %%
plt.plot(df['Time Span'], df['Pulse'])
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("Simple Line plot")
plt.show()
